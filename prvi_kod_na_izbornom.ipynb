# %% [markdown]
# <a href="https://colab.research.google.com/github/pericrea-dotcom/kolegij-AI-znanosti-/blob/main/prvi_kod_na_izbornom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = (2,3,4)

# %%
n
# Out:
# (2, 3, 4)
